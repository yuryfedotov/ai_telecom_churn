# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina' # Make matplotlib render retina-quality charts
import seaborn as sns
from IPython.display import display

# %% [markdown]
# ## 1. First look at the data

# %%
data = pd.read_csv('dataset.csv')

# Some values in TotalCharges were not able to load as numeric.
# I manually handle it by replacing them by the product of tenure and monthly charges.
data.TotalCharges = pd.to_numeric(data.TotalCharges, errors='coerce')
data.loc[data.TotalCharges.isnull(), 'TotalCharges'] = data.tenure * data.MonthlyCharges

print("Original dataset sample:")
display(data.head(5))
display(data.info())
# Out:
# Original dataset sample:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0           Electronic check          29.85         29.85     No
# 1               Mailed check          56.95       1889.50     No
# 2               Mailed check          53.85        108.15    Yes
# 3  Bank transfer (automatic)          42.30       1840.75     No
# 4           Electronic check          70.70        151.65    Yes
#
# [5 rows x 21 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB
# None

# %% [markdown]
# ### What do I notice immediately:
# - The quality of data is really good. It was clear from Kaggle's preview, and now confirmed. There are no missing values, and all columns have meaningful sense and values.
# - "customerID" column contains unique IDs (confirmed at Kaggle's preview), so we can delete it.
# - Since a lot of feature are multi-level categorical features, we will need to do a lot of encoding.

# %% [markdown]
# ## 2. Feature-by feature analysis
# **Important**: if I decide to drop or encode some features, I will consecutively add their names to special lists initialized in the cell below, and delete/encode them in 1 line in the end of the feature-by-feature analysis.

# %%
columns_to_delete = [] # Here we will accumulate names of columns for deletion
columns_to_encode = [] # Here we will accumulate names of columns for encoding

def plot_crosstab_and_value_counts_againts_target(categorical_feature):
    """This function takes a name of a categorical feature as string,
    and plots crosstab and value_counts of it versus the target."""
    
    print("Count of values: {} versus Churn:".format(categorical_feature))
    display(pd.crosstab(data.Churn, data[categorical_feature], margins=True).style.background_gradient(cmap='summer_r'))
    print("Average churn rate for each {}:".format(categorical_feature))
    display(data.groupby(categorical_feature)['Churn'].mean().sort_values(ascending=False))
    
def display_correlation_with_binned_version(numerical_feature):
    """This function takes a name of a numerical feature as string,
    and plots crosstab and value_counts of it 5-binned version versus the target."""
    
    feature_binned_name = numerical_feature + "_binned"
    data[feature_binned_name] = pd.cut(data[numerical_feature], bins = 5)
    plot_crosstab_and_value_counts_againts_target(feature_binned_name)
    data.drop(feature_binned_name, axis = 1, inplace = True)

# %% [markdown]
# ### (Target) Churn
# This column is binary, and contains string values "Yes" and "No". Let's encode it to boolean at the beginning, because it will allow us to calculate average churn rates per different dimensions of data.

# %%
data.Churn = data.Churn.map({"Yes": 1, "No": 0})

# %% [markdown]
# ### (1/20) customerID
# As was indicate above, this feature can be deleted.

# %%
columns_to_delete.append("customerID")

# %% [markdown]
# ### (2/20) gender – whether the customer is a male or a female

# %%
plot_crosstab_and_value_counts_againts_target('gender')
columns_to_delete.append("gender")
# Out:
# Count of values: gender versus Churn:
# <style  type="text/css" >
#     #T_b2231516_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #5eae66;
#             color:  #000000;
#         }    #T_b2231516_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #5aac66;
#             color:  #000000;
#         }    #T_b2231516_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b2231516_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2231516_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2231516_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2231516_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2231516_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2231516_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b2231516_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >gender</th>        <th class="col_heading level0 col0" >Female</th>        <th class="col_heading level0 col1" >Male</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b2231516_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b2231516_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >2549</td>
#                         <td id="T_b2231516_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >2625</td>
#                         <td id="T_b2231516_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b2231516_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b2231516_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >939</td>
#                         <td id="T_b2231516_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >930</td>
#                         <td id="T_b2231516_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b2231516_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b2231516_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >3488</td>
#                         <td id="T_b2231516_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >3555</td>
#                         <td id="T_b2231516_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each gender:
# gender
# Female    0.269209
# Male      0.261603
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: this feature alone seems to have no correlation with the target. **Don't include** in the models.

# %% [markdown]
# ### (3/20) SeniorCitizen – whether the customer is a senior citizen or not (1, 0)

# %%
plot_crosstab_and_value_counts_againts_target('SeniorCitizen')
# Out:
# Count of values: SeniorCitizen versus Churn:
# <style  type="text/css" >
#     #T_b22e9724_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #4fa766;
#             color:  #000000;
#         }    #T_b22e9724_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #b6db66;
#             color:  #000000;
#         }    #T_b22e9724_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b22e9724_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b22e9724_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b22e9724_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b22e9724_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b22e9724_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b22e9724_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b22e9724_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >SeniorCitizen</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b22e9724_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b22e9724_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >4508</td>
#                         <td id="T_b22e9724_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >666</td>
#                         <td id="T_b22e9724_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b22e9724_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b22e9724_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >1393</td>
#                         <td id="T_b22e9724_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >476</td>
#                         <td id="T_b22e9724_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b22e9724_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b22e9724_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >5901</td>
#                         <td id="T_b22e9724_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >1142</td>
#                         <td id="T_b22e9724_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each SeniorCitizen:
# SeniorCitizen
# 1    0.416813
# 0    0.236062
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: for both senior and non-senior citizens, the churn rate is <50%. However, for senior citizens it is 2 times higher than for non-senior! We will include this feature in the model. **Include** in the models.

# %% [markdown]
# ### (4/20) Partner – whether the customer has a partner or not

# %%
plot_crosstab_and_value_counts_againts_target('Partner')
columns_to_encode.append('Partner')
# Out:
# Count of values: Partner versus Churn:
# <style  type="text/css" >
#     #T_b237d2b2_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #7dbe66;
#             color:  #000000;
#         }    #T_b237d2b2_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #3e9e66;
#             color:  #000000;
#         }    #T_b237d2b2_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b237d2b2_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b237d2b2_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b237d2b2_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b237d2b2_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b237d2b2_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b237d2b2_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b237d2b2_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >Partner</th>        <th class="col_heading level0 col0" >No</th>        <th class="col_heading level0 col1" >Yes</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b237d2b2_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b237d2b2_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >2441</td>
#                         <td id="T_b237d2b2_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >2733</td>
#                         <td id="T_b237d2b2_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b237d2b2_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b237d2b2_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >1200</td>
#                         <td id="T_b237d2b2_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >669</td>
#                         <td id="T_b237d2b2_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b237d2b2_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b237d2b2_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >3641</td>
#                         <td id="T_b237d2b2_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >3402</td>
#                         <td id="T_b237d2b2_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each Partner:
# Partner
# No     0.329580
# Yes    0.196649
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: **Include** in the models. We see the big difference in average churn rate between the category classes.

# %% [markdown]
# ### (5/20) Dependents – whether the customer has dependents or not (Yes, No)

# %%
plot_crosstab_and_value_counts_againts_target('Dependents')
columns_to_encode.append('Dependents')
# Out:
# Count of values: Dependents versus Churn:
# <style  type="text/css" >
#     #T_b24109cc_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #74ba66;
#             color:  #000000;
#         }    #T_b24109cc_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #2e9666;
#             color:  #000000;
#         }    #T_b24109cc_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b24109cc_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b24109cc_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b24109cc_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b24109cc_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b24109cc_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b24109cc_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b24109cc_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >Dependents</th>        <th class="col_heading level0 col0" >No</th>        <th class="col_heading level0 col1" >Yes</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b24109cc_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b24109cc_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >3390</td>
#                         <td id="T_b24109cc_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >1784</td>
#                         <td id="T_b24109cc_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b24109cc_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b24109cc_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >1543</td>
#                         <td id="T_b24109cc_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >326</td>
#                         <td id="T_b24109cc_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b24109cc_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b24109cc_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >4933</td>
#                         <td id="T_b24109cc_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >2110</td>
#                         <td id="T_b24109cc_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each Dependents:
# Dependents
# No     0.312791
# Yes    0.154502
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: **Include** in the models. We see the big difference in average churn rate between the category classes.

# %% [markdown]
# ### (6/20) tenure – number of months the customer has stayed with the company

# %%
display_correlation_with_binned_version('tenure')
# Out:
# Count of values: tenure_binned versus Churn:
# <style  type="text/css" >
#     #T_b24e55fa_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #ddee66;
#             color:  #000000;
#         }    #T_b24e55fa_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #5aac66;
#             color:  #000000;
#         }    #T_b24e55fa_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #47a366;
#             color:  #000000;
#         }    #T_b24e55fa_7688_11ea_ba57_8c85904b4670row0_col3 {
#             background-color:  #2d9666;
#             color:  #000000;
#         }    #T_b24e55fa_7688_11ea_ba57_8c85904b4670row0_col4 {
#             background-color:  #148a66;
#             color:  #000000;
#         }    #T_b24e55fa_7688_11ea_ba57_8c85904b4670row0_col5 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b24e55fa_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b24e55fa_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b24e55fa_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b24e55fa_7688_11ea_ba57_8c85904b4670row1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b24e55fa_7688_11ea_ba57_8c85904b4670row1_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b24e55fa_7688_11ea_ba57_8c85904b4670row1_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b24e55fa_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b24e55fa_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b24e55fa_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b24e55fa_7688_11ea_ba57_8c85904b4670row2_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b24e55fa_7688_11ea_ba57_8c85904b4670row2_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b24e55fa_7688_11ea_ba57_8c85904b4670row2_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b24e55fa_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >tenure_binned</th>        <th class="col_heading level0 col0" >(-0.072, 14.4]</th>        <th class="col_heading level0 col1" >(14.4, 28.8]</th>        <th class="col_heading level0 col2" >(28.8, 43.2]</th>        <th class="col_heading level0 col3" >(43.2, 57.6]</th>        <th class="col_heading level0 col4" >(57.6, 72.0]</th>        <th class="col_heading level0 col5" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b24e55fa_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b24e55fa_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >1272</td>
#                         <td id="T_b24e55fa_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >831</td>
#                         <td id="T_b24e55fa_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >774</td>
#                         <td id="T_b24e55fa_7688_11ea_ba57_8c85904b4670row0_col3" class="data row0 col3" >805</td>
#                         <td id="T_b24e55fa_7688_11ea_ba57_8c85904b4670row0_col4" class="data row0 col4" >1492</td>
#                         <td id="T_b24e55fa_7688_11ea_ba57_8c85904b4670row0_col5" class="data row0 col5" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b24e55fa_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b24e55fa_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >1099</td>
#                         <td id="T_b24e55fa_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >295</td>
#                         <td id="T_b24e55fa_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >215</td>
#                         <td id="T_b24e55fa_7688_11ea_ba57_8c85904b4670row1_col3" class="data row1 col3" >142</td>
#                         <td id="T_b24e55fa_7688_11ea_ba57_8c85904b4670row1_col4" class="data row1 col4" >118</td>
#                         <td id="T_b24e55fa_7688_11ea_ba57_8c85904b4670row1_col5" class="data row1 col5" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b24e55fa_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b24e55fa_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >2371</td>
#                         <td id="T_b24e55fa_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >1126</td>
#                         <td id="T_b24e55fa_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >989</td>
#                         <td id="T_b24e55fa_7688_11ea_ba57_8c85904b4670row2_col3" class="data row2 col3" >947</td>
#                         <td id="T_b24e55fa_7688_11ea_ba57_8c85904b4670row2_col4" class="data row2 col4" >1610</td>
#                         <td id="T_b24e55fa_7688_11ea_ba57_8c85904b4670row2_col5" class="data row2 col5" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each tenure_binned:
# tenure_binned
# (-0.072, 14.4]    0.463518
# (14.4, 28.8]      0.261989
# (28.8, 43.2]      0.217391
# (43.2, 57.6]      0.149947
# (57.6, 72.0]      0.073292
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: **Include** in the models. We see clear negative correlation between the tenure and the churn rate.

# %% [markdown]
# ### (7/20) PhoneService – whether the customer has a phone service or not (Yes, No)

# %%
plot_crosstab_and_value_counts_againts_target('PhoneService')
columns_to_delete.append('PhoneService')
# Out:
# Count of values: PhoneService versus Churn:
# <style  type="text/css" >
#     #T_b25773b0_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #54aa66;
#             color:  #000000;
#         }    #T_b25773b0_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #5dae66;
#             color:  #000000;
#         }    #T_b25773b0_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b25773b0_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b25773b0_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b25773b0_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b25773b0_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b25773b0_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b25773b0_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b25773b0_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >PhoneService</th>        <th class="col_heading level0 col0" >No</th>        <th class="col_heading level0 col1" >Yes</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b25773b0_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b25773b0_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >512</td>
#                         <td id="T_b25773b0_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >4662</td>
#                         <td id="T_b25773b0_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b25773b0_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b25773b0_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >170</td>
#                         <td id="T_b25773b0_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >1699</td>
#                         <td id="T_b25773b0_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b25773b0_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b25773b0_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >682</td>
#                         <td id="T_b25773b0_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >6361</td>
#                         <td id="T_b25773b0_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each PhoneService:
# PhoneService
# Yes    0.267096
# No     0.249267
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: this feature alone seems to have no correlation with the target. **Don't include** in the models.

# %% [markdown]
# ### (8/20) MultipleLines – whether the customer has multiple lines or not (Yes, No, No phone service)

# %%
plot_crosstab_and_value_counts_againts_target('MultipleLines')
columns_to_delete.append('MultipleLines')
# Out:
# Count of values: MultipleLines versus Churn:
# <style  type="text/css" >
#     #T_b2612e5a_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #55aa66;
#             color:  #000000;
#         }    #T_b2612e5a_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #54aa66;
#             color:  #000000;
#         }    #T_b2612e5a_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #66b266;
#             color:  #000000;
#         }    #T_b2612e5a_7688_11ea_ba57_8c85904b4670row0_col3 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b2612e5a_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2612e5a_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2612e5a_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2612e5a_7688_11ea_ba57_8c85904b4670row1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2612e5a_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2612e5a_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2612e5a_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2612e5a_7688_11ea_ba57_8c85904b4670row2_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b2612e5a_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >MultipleLines</th>        <th class="col_heading level0 col0" >No</th>        <th class="col_heading level0 col1" >No phone service</th>        <th class="col_heading level0 col2" >Yes</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b2612e5a_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b2612e5a_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >2541</td>
#                         <td id="T_b2612e5a_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >512</td>
#                         <td id="T_b2612e5a_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >2121</td>
#                         <td id="T_b2612e5a_7688_11ea_ba57_8c85904b4670row0_col3" class="data row0 col3" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b2612e5a_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b2612e5a_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >849</td>
#                         <td id="T_b2612e5a_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >170</td>
#                         <td id="T_b2612e5a_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >850</td>
#                         <td id="T_b2612e5a_7688_11ea_ba57_8c85904b4670row1_col3" class="data row1 col3" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b2612e5a_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b2612e5a_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >3390</td>
#                         <td id="T_b2612e5a_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >682</td>
#                         <td id="T_b2612e5a_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >2971</td>
#                         <td id="T_b2612e5a_7688_11ea_ba57_8c85904b4670row2_col3" class="data row2 col3" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each MultipleLines:
# MultipleLines
# Yes                 0.286099
# No                  0.250442
# No phone service    0.249267
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: this feature alone seems to have no correlation with the target. **Don't include** in the models.

# %% [markdown]
# ### (9/20) InternetService – customer’s internet service provider (DSL, Fiber optic, No)

# %%
plot_crosstab_and_value_counts_againts_target('InternetService')
columns_to_encode.append('InternetService')
# Out:
# Count of values: InternetService versus Churn:
# <style  type="text/css" >
#     #T_b26ae83c_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #3b9d66;
#             color:  #000000;
#         }    #T_b26ae83c_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #b8dc66;
#             color:  #000000;
#         }    #T_b26ae83c_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #148a66;
#             color:  #000000;
#         }    #T_b26ae83c_7688_11ea_ba57_8c85904b4670row0_col3 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b26ae83c_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b26ae83c_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b26ae83c_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b26ae83c_7688_11ea_ba57_8c85904b4670row1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b26ae83c_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b26ae83c_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b26ae83c_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b26ae83c_7688_11ea_ba57_8c85904b4670row2_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b26ae83c_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >InternetService</th>        <th class="col_heading level0 col0" >DSL</th>        <th class="col_heading level0 col1" >Fiber optic</th>        <th class="col_heading level0 col2" >No</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b26ae83c_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b26ae83c_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >1962</td>
#                         <td id="T_b26ae83c_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >1799</td>
#                         <td id="T_b26ae83c_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >1413</td>
#                         <td id="T_b26ae83c_7688_11ea_ba57_8c85904b4670row0_col3" class="data row0 col3" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b26ae83c_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b26ae83c_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >459</td>
#                         <td id="T_b26ae83c_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >1297</td>
#                         <td id="T_b26ae83c_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >113</td>
#                         <td id="T_b26ae83c_7688_11ea_ba57_8c85904b4670row1_col3" class="data row1 col3" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b26ae83c_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b26ae83c_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >2421</td>
#                         <td id="T_b26ae83c_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >3096</td>
#                         <td id="T_b26ae83c_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >1526</td>
#                         <td id="T_b26ae83c_7688_11ea_ba57_8c85904b4670row2_col3" class="data row2 col3" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each InternetService:
# InternetService
# Fiber optic    0.418928
# DSL            0.189591
# No             0.074050
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: **Include** in the models. We see the big difference in average churn rate between the category classes.

# %% [markdown]
# ### (10/20) OnlineSecurity – whether the customer has online security or not (Yes, No, No internet service)

# %%
plot_crosstab_and_value_counts_againts_target('OnlineSecurity')
columns_to_encode.append('OnlineSecurity')
# Out:
# Count of values: OnlineSecurity versus Churn:
# <style  type="text/css" >
#     #T_b274e904_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #b7db66;
#             color:  #000000;
#         }    #T_b274e904_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #148a66;
#             color:  #000000;
#         }    #T_b274e904_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #2b9566;
#             color:  #000000;
#         }    #T_b274e904_7688_11ea_ba57_8c85904b4670row0_col3 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b274e904_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b274e904_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b274e904_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b274e904_7688_11ea_ba57_8c85904b4670row1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b274e904_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b274e904_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b274e904_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b274e904_7688_11ea_ba57_8c85904b4670row2_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b274e904_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >OnlineSecurity</th>        <th class="col_heading level0 col0" >No</th>        <th class="col_heading level0 col1" >No internet service</th>        <th class="col_heading level0 col2" >Yes</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b274e904_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b274e904_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >2037</td>
#                         <td id="T_b274e904_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >1413</td>
#                         <td id="T_b274e904_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >1724</td>
#                         <td id="T_b274e904_7688_11ea_ba57_8c85904b4670row0_col3" class="data row0 col3" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b274e904_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b274e904_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >1461</td>
#                         <td id="T_b274e904_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >113</td>
#                         <td id="T_b274e904_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >295</td>
#                         <td id="T_b274e904_7688_11ea_ba57_8c85904b4670row1_col3" class="data row1 col3" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b274e904_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b274e904_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >3498</td>
#                         <td id="T_b274e904_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >1526</td>
#                         <td id="T_b274e904_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >2019</td>
#                         <td id="T_b274e904_7688_11ea_ba57_8c85904b4670row2_col3" class="data row2 col3" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each OnlineSecurity:
# OnlineSecurity
# No                     0.417667
# Yes                    0.146112
# No internet service    0.074050
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: **Include** in the models. We see the big difference in average churn rate between the category classes.

# %% [markdown]
# ### (11/20) OnlineBackup – whether the customer has online backup or not (Yes, No, No internet service)

# %%
plot_crosstab_and_value_counts_againts_target('OnlineBackup')
columns_to_encode.append('OnlineBackup')
# Out:
# Count of values: OnlineBackup versus Churn:
# <style  type="text/css" >
#     #T_b2812110_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #aad466;
#             color:  #000000;
#         }    #T_b2812110_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #148a66;
#             color:  #000000;
#         }    #T_b2812110_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #46a266;
#             color:  #000000;
#         }    #T_b2812110_7688_11ea_ba57_8c85904b4670row0_col3 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b2812110_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2812110_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2812110_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2812110_7688_11ea_ba57_8c85904b4670row1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2812110_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2812110_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2812110_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2812110_7688_11ea_ba57_8c85904b4670row2_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b2812110_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >OnlineBackup</th>        <th class="col_heading level0 col0" >No</th>        <th class="col_heading level0 col1" >No internet service</th>        <th class="col_heading level0 col2" >Yes</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b2812110_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b2812110_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >1855</td>
#                         <td id="T_b2812110_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >1413</td>
#                         <td id="T_b2812110_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >1906</td>
#                         <td id="T_b2812110_7688_11ea_ba57_8c85904b4670row0_col3" class="data row0 col3" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b2812110_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b2812110_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >1233</td>
#                         <td id="T_b2812110_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >113</td>
#                         <td id="T_b2812110_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >523</td>
#                         <td id="T_b2812110_7688_11ea_ba57_8c85904b4670row1_col3" class="data row1 col3" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b2812110_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b2812110_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >3088</td>
#                         <td id="T_b2812110_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >1526</td>
#                         <td id="T_b2812110_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >2429</td>
#                         <td id="T_b2812110_7688_11ea_ba57_8c85904b4670row2_col3" class="data row2 col3" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each OnlineBackup:
# OnlineBackup
# No                     0.399288
# Yes                    0.215315
# No internet service    0.074050
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: **Include** in the models. We see the big difference in average churn rate between the category classes.

# %% [markdown]
# ### (12/20) DeviceProtection – whether the customer has device protection or not (Yes, No, No internet service)

# %%
plot_crosstab_and_value_counts_againts_target('DeviceProtection')
columns_to_encode.append('DeviceProtection')
# Out:
# Count of values: DeviceProtection versus Churn:
# <style  type="text/css" >
#     #T_b290f216_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #a4d266;
#             color:  #000000;
#         }    #T_b290f216_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #148a66;
#             color:  #000000;
#         }    #T_b290f216_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #4aa466;
#             color:  #000000;
#         }    #T_b290f216_7688_11ea_ba57_8c85904b4670row0_col3 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b290f216_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b290f216_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b290f216_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b290f216_7688_11ea_ba57_8c85904b4670row1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b290f216_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b290f216_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b290f216_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b290f216_7688_11ea_ba57_8c85904b4670row2_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b290f216_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >DeviceProtection</th>        <th class="col_heading level0 col0" >No</th>        <th class="col_heading level0 col1" >No internet service</th>        <th class="col_heading level0 col2" >Yes</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b290f216_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b290f216_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >1884</td>
#                         <td id="T_b290f216_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >1413</td>
#                         <td id="T_b290f216_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >1877</td>
#                         <td id="T_b290f216_7688_11ea_ba57_8c85904b4670row0_col3" class="data row0 col3" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b290f216_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b290f216_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >1211</td>
#                         <td id="T_b290f216_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >113</td>
#                         <td id="T_b290f216_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >545</td>
#                         <td id="T_b290f216_7688_11ea_ba57_8c85904b4670row1_col3" class="data row1 col3" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b290f216_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b290f216_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >3095</td>
#                         <td id="T_b290f216_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >1526</td>
#                         <td id="T_b290f216_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >2422</td>
#                         <td id="T_b290f216_7688_11ea_ba57_8c85904b4670row2_col3" class="data row2 col3" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each DeviceProtection:
# DeviceProtection
# No                     0.391276
# Yes                    0.225021
# No internet service    0.074050
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: **Include** in the models. We see the big difference in average churn rate between the category classes.

# %% [markdown]
# ### (13/20) TechSupport – whether the customer has tech support or not (Yes, No, No internet service)

# %%
plot_crosstab_and_value_counts_againts_target('TechSupport')
columns_to_encode.append('TechSupport')
# Out:
# Count of values: TechSupport versus Churn:
# <style  type="text/css" >
#     #T_b29ac5e8_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #b6db66;
#             color:  #000000;
#         }    #T_b29ac5e8_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #148a66;
#             color:  #000000;
#         }    #T_b29ac5e8_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #2d9666;
#             color:  #000000;
#         }    #T_b29ac5e8_7688_11ea_ba57_8c85904b4670row0_col3 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b29ac5e8_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b29ac5e8_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b29ac5e8_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b29ac5e8_7688_11ea_ba57_8c85904b4670row1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b29ac5e8_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b29ac5e8_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b29ac5e8_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b29ac5e8_7688_11ea_ba57_8c85904b4670row2_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b29ac5e8_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >TechSupport</th>        <th class="col_heading level0 col0" >No</th>        <th class="col_heading level0 col1" >No internet service</th>        <th class="col_heading level0 col2" >Yes</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b29ac5e8_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b29ac5e8_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >2027</td>
#                         <td id="T_b29ac5e8_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >1413</td>
#                         <td id="T_b29ac5e8_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >1734</td>
#                         <td id="T_b29ac5e8_7688_11ea_ba57_8c85904b4670row0_col3" class="data row0 col3" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b29ac5e8_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b29ac5e8_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >1446</td>
#                         <td id="T_b29ac5e8_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >113</td>
#                         <td id="T_b29ac5e8_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >310</td>
#                         <td id="T_b29ac5e8_7688_11ea_ba57_8c85904b4670row1_col3" class="data row1 col3" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b29ac5e8_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b29ac5e8_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >3473</td>
#                         <td id="T_b29ac5e8_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >1526</td>
#                         <td id="T_b29ac5e8_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >2044</td>
#                         <td id="T_b29ac5e8_7688_11ea_ba57_8c85904b4670row2_col3" class="data row2 col3" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each TechSupport:
# TechSupport
# No                     0.416355
# Yes                    0.151663
# No internet service    0.074050
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: **Include** in the models. We see the big difference in average churn rate between the category classes.

# %% [markdown]
# ### (14/20) StreamingTV – whether the customer has streaming TV or not (Yes, No, No internet service)

# %%
plot_crosstab_and_value_counts_againts_target('StreamingTV')
columns_to_delete.append('StreamingTV')
# Out:
# Count of values: StreamingTV versus Churn:
# <style  type="text/css" >
#     #T_b2a38962_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #81c066;
#             color:  #000000;
#         }    #T_b2a38962_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #148a66;
#             color:  #000000;
#         }    #T_b2a38962_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #6eb666;
#             color:  #000000;
#         }    #T_b2a38962_7688_11ea_ba57_8c85904b4670row0_col3 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b2a38962_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2a38962_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2a38962_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2a38962_7688_11ea_ba57_8c85904b4670row1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2a38962_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2a38962_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2a38962_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2a38962_7688_11ea_ba57_8c85904b4670row2_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b2a38962_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >StreamingTV</th>        <th class="col_heading level0 col0" >No</th>        <th class="col_heading level0 col1" >No internet service</th>        <th class="col_heading level0 col2" >Yes</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b2a38962_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b2a38962_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >1868</td>
#                         <td id="T_b2a38962_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >1413</td>
#                         <td id="T_b2a38962_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >1893</td>
#                         <td id="T_b2a38962_7688_11ea_ba57_8c85904b4670row0_col3" class="data row0 col3" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b2a38962_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b2a38962_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >942</td>
#                         <td id="T_b2a38962_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >113</td>
#                         <td id="T_b2a38962_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >814</td>
#                         <td id="T_b2a38962_7688_11ea_ba57_8c85904b4670row1_col3" class="data row1 col3" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b2a38962_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b2a38962_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >2810</td>
#                         <td id="T_b2a38962_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >1526</td>
#                         <td id="T_b2a38962_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >2707</td>
#                         <td id="T_b2a38962_7688_11ea_ba57_8c85904b4670row2_col3" class="data row2 col3" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each StreamingTV:
# StreamingTV
# No                     0.335231
# Yes                    0.300702
# No internet service    0.074050
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: this feature alone seems to have no correlation with the target. **Don't include** in the models.

# %% [markdown]
# ### (15/20) StreamingMovies – whether the customer has streaming movies or not (Yes, No, No internet service)

# %%
plot_crosstab_and_value_counts_againts_target('StreamingMovies')
columns_to_delete.append('StreamingMovies')
# Out:
# Count of values: StreamingMovies versus Churn:
# <style  type="text/css" >
#     #T_b2ad73dc_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #82c066;
#             color:  #000000;
#         }    #T_b2ad73dc_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #148a66;
#             color:  #000000;
#         }    #T_b2ad73dc_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #6db666;
#             color:  #000000;
#         }    #T_b2ad73dc_7688_11ea_ba57_8c85904b4670row0_col3 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b2ad73dc_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2ad73dc_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2ad73dc_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2ad73dc_7688_11ea_ba57_8c85904b4670row1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2ad73dc_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2ad73dc_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2ad73dc_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2ad73dc_7688_11ea_ba57_8c85904b4670row2_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b2ad73dc_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >StreamingMovies</th>        <th class="col_heading level0 col0" >No</th>        <th class="col_heading level0 col1" >No internet service</th>        <th class="col_heading level0 col2" >Yes</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b2ad73dc_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b2ad73dc_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >1847</td>
#                         <td id="T_b2ad73dc_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >1413</td>
#                         <td id="T_b2ad73dc_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >1914</td>
#                         <td id="T_b2ad73dc_7688_11ea_ba57_8c85904b4670row0_col3" class="data row0 col3" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b2ad73dc_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b2ad73dc_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >938</td>
#                         <td id="T_b2ad73dc_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >113</td>
#                         <td id="T_b2ad73dc_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >818</td>
#                         <td id="T_b2ad73dc_7688_11ea_ba57_8c85904b4670row1_col3" class="data row1 col3" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b2ad73dc_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b2ad73dc_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >2785</td>
#                         <td id="T_b2ad73dc_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >1526</td>
#                         <td id="T_b2ad73dc_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >2732</td>
#                         <td id="T_b2ad73dc_7688_11ea_ba57_8c85904b4670row2_col3" class="data row2 col3" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each StreamingMovies:
# StreamingMovies
# No                     0.336804
# Yes                    0.299414
# No internet service    0.074050
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: this feature alone seems to have no correlation with the target. **Don't include** in the models.

# %% [markdown]
# ### (16/20) Contract – the contract term of the customer (Month-to-month, One year, Two year)

# %%
plot_crosstab_and_value_counts_againts_target('Contract')
columns_to_encode.append('Contract')
# Out:
# Count of values: Contract versus Churn:
# <style  type="text/css" >
#     #T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #bede66;
#             color:  #000000;
#         }    #T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #209066;
#             color:  #000000;
#         }    #T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #078366;
#             color:  #f1f1f1;
#         }    #T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row0_col3 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row2_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b2b6fd3a_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >Contract</th>        <th class="col_heading level0 col0" >Month-to-month</th>        <th class="col_heading level0 col1" >One year</th>        <th class="col_heading level0 col2" >Two year</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b2b6fd3a_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >2220</td>
#                         <td id="T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >1307</td>
#                         <td id="T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >1647</td>
#                         <td id="T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row0_col3" class="data row0 col3" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b2b6fd3a_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >1655</td>
#                         <td id="T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >166</td>
#                         <td id="T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >48</td>
#                         <td id="T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row1_col3" class="data row1 col3" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b2b6fd3a_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >3875</td>
#                         <td id="T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >1473</td>
#                         <td id="T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >1695</td>
#                         <td id="T_b2b6fd3a_7688_11ea_ba57_8c85904b4670row2_col3" class="data row2 col3" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each Contract:
# Contract
# Month-to-month    0.427097
# One year          0.112695
# Two year          0.028319
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: **Include** in the models. We see the big difference in average churn rate between the category classes.

# %% [markdown]
# ### (17/20) PaperlessBilling – whether the customer has paperless billing or not (Yes, No)

# %%
plot_crosstab_and_value_counts_againts_target('PaperlessBilling')
columns_to_encode.append('PaperlessBilling')
# Out:
# Count of values: PaperlessBilling versus Churn:
# <style  type="text/css" >
#     #T_b2c08184_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #319866;
#             color:  #000000;
#         }    #T_b2c08184_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #81c066;
#             color:  #000000;
#         }    #T_b2c08184_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b2c08184_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2c08184_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2c08184_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2c08184_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2c08184_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2c08184_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b2c08184_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >PaperlessBilling</th>        <th class="col_heading level0 col0" >No</th>        <th class="col_heading level0 col1" >Yes</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b2c08184_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b2c08184_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >2403</td>
#                         <td id="T_b2c08184_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >2771</td>
#                         <td id="T_b2c08184_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b2c08184_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b2c08184_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >469</td>
#                         <td id="T_b2c08184_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >1400</td>
#                         <td id="T_b2c08184_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b2c08184_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b2c08184_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >2872</td>
#                         <td id="T_b2c08184_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >4171</td>
#                         <td id="T_b2c08184_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each PaperlessBilling:
# PaperlessBilling
# Yes    0.335651
# No     0.163301
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: **Include** in the models. We see the big difference in average churn rate between the category classes.

# %% [markdown]
# ### (18/20) PaymentMethod – the customer’s payment method (Electronic check, Mailed check, Bank transfer (automatic), Credit card (automatic))

# %%
plot_crosstab_and_value_counts_againts_target('PaymentMethod')
columns_to_encode.append('PaymentMethod')
# Out:
# Count of values: PaymentMethod versus Churn:
# <style  type="text/css" >
#     #T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #339966;
#             color:  #000000;
#         }    #T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #2e9666;
#             color:  #000000;
#         }    #T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #d3e966;
#             color:  #000000;
#         }    #T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row0_col3 {
#             background-color:  #3c9e66;
#             color:  #000000;
#         }    #T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row0_col4 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row1_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row2_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row2_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >PaymentMethod</th>        <th class="col_heading level0 col0" >Bank transfer (automatic)</th>        <th class="col_heading level0 col1" >Credit card (automatic)</th>        <th class="col_heading level0 col2" >Electronic check</th>        <th class="col_heading level0 col3" >Mailed check</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >1286</td>
#                         <td id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >1290</td>
#                         <td id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >1294</td>
#                         <td id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row0_col3" class="data row0 col3" >1304</td>
#                         <td id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row0_col4" class="data row0 col4" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >258</td>
#                         <td id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >232</td>
#                         <td id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >1071</td>
#                         <td id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row1_col3" class="data row1 col3" >308</td>
#                         <td id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row1_col4" class="data row1 col4" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >1544</td>
#                         <td id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >1522</td>
#                         <td id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >2365</td>
#                         <td id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row2_col3" class="data row2 col3" >1612</td>
#                         <td id="T_b2ca6f3c_7688_11ea_ba57_8c85904b4670row2_col4" class="data row2 col4" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each PaymentMethod:
# PaymentMethod
# Electronic check             0.452854
# Mailed check                 0.191067
# Bank transfer (automatic)    0.167098
# Credit card (automatic)      0.152431
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: **Include** in the models. We see the big difference in average churn rate between the category classes.

# %% [markdown]
# ### (19/20) MonthlyCharges – the amount charged to the customer monthly

# %%
display_correlation_with_binned_version('MonthlyCharges')
# Out:
# Count of values: MonthlyCharges_binned versus Churn:
# <style  type="text/css" >
#     #T_b2d88a9a_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #209066;
#             color:  #000000;
#         }    #T_b2d88a9a_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #5eae66;
#             color:  #000000;
#         }    #T_b2d88a9a_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #6bb566;
#             color:  #000000;
#         }    #T_b2d88a9a_7688_11ea_ba57_8c85904b4670row0_col3 {
#             background-color:  #96cb66;
#             color:  #000000;
#         }    #T_b2d88a9a_7688_11ea_ba57_8c85904b4670row0_col4 {
#             background-color:  #6eb666;
#             color:  #000000;
#         }    #T_b2d88a9a_7688_11ea_ba57_8c85904b4670row0_col5 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b2d88a9a_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2d88a9a_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2d88a9a_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2d88a9a_7688_11ea_ba57_8c85904b4670row1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2d88a9a_7688_11ea_ba57_8c85904b4670row1_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2d88a9a_7688_11ea_ba57_8c85904b4670row1_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2d88a9a_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2d88a9a_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2d88a9a_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2d88a9a_7688_11ea_ba57_8c85904b4670row2_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2d88a9a_7688_11ea_ba57_8c85904b4670row2_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2d88a9a_7688_11ea_ba57_8c85904b4670row2_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >MonthlyCharges_binned</th>        <th class="col_heading level0 col0" >(18.15, 38.35]</th>        <th class="col_heading level0 col1" >(38.35, 58.45]</th>        <th class="col_heading level0 col2" >(58.45, 78.55]</th>        <th class="col_heading level0 col3" >(78.55, 98.65]</th>        <th class="col_heading level0 col4" >(98.65, 118.75]</th>        <th class="col_heading level0 col5" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >1592</td>
#                         <td id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >734</td>
#                         <td id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >964</td>
#                         <td id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670row0_col3" class="data row0 col3" >1151</td>
#                         <td id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670row0_col4" class="data row0 col4" >733</td>
#                         <td id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670row0_col5" class="data row0 col5" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >205</td>
#                         <td id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >271</td>
#                         <td id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >403</td>
#                         <td id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670row1_col3" class="data row1 col3" >675</td>
#                         <td id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670row1_col4" class="data row1 col4" >315</td>
#                         <td id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670row1_col5" class="data row1 col5" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >1797</td>
#                         <td id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >1005</td>
#                         <td id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >1367</td>
#                         <td id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670row2_col3" class="data row2 col3" >1826</td>
#                         <td id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670row2_col4" class="data row2 col4" >1048</td>
#                         <td id="T_b2d88a9a_7688_11ea_ba57_8c85904b4670row2_col5" class="data row2 col5" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each MonthlyCharges_binned:
# MonthlyCharges_binned
# (78.55, 98.65]     0.369660
# (98.65, 118.75]    0.300573
# (58.45, 78.55]     0.294806
# (38.35, 58.45]     0.269652
# (18.15, 38.35]     0.114079
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: **Include** in the models. We see clear positive correlation between the monthly charges and churn rate.

# %% [markdown]
# ### (20/20) TotalCharges – the total amount charged to the customer

# %%
display_correlation_with_binned_version('TotalCharges')
# Out:
# Count of values: TotalCharges_binned versus Churn:
# <style  type="text/css" >
#     #T_b2e6f526_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #7dbe66;
#             color:  #000000;
#         }    #T_b2e6f526_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #53a966;
#             color:  #000000;
#         }    #T_b2e6f526_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #339966;
#             color:  #000000;
#         }    #T_b2e6f526_7688_11ea_ba57_8c85904b4670row0_col3 {
#             background-color:  #2c9666;
#             color:  #000000;
#         }    #T_b2e6f526_7688_11ea_ba57_8c85904b4670row0_col4 {
#             background-color:  #1e8e66;
#             color:  #000000;
#         }    #T_b2e6f526_7688_11ea_ba57_8c85904b4670row0_col5 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b2e6f526_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2e6f526_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2e6f526_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2e6f526_7688_11ea_ba57_8c85904b4670row1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2e6f526_7688_11ea_ba57_8c85904b4670row1_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2e6f526_7688_11ea_ba57_8c85904b4670row1_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2e6f526_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2e6f526_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2e6f526_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2e6f526_7688_11ea_ba57_8c85904b4670row2_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2e6f526_7688_11ea_ba57_8c85904b4670row2_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2e6f526_7688_11ea_ba57_8c85904b4670row2_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b2e6f526_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >TotalCharges_binned</th>        <th class="col_heading level0 col0" >(-8.685, 1736.96]</th>        <th class="col_heading level0 col1" >(1736.96, 3473.92]</th>        <th class="col_heading level0 col2" >(3473.92, 5210.88]</th>        <th class="col_heading level0 col3" >(5210.88, 6947.84]</th>        <th class="col_heading level0 col4" >(6947.84, 8684.8]</th>        <th class="col_heading level0 col5" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b2e6f526_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b2e6f526_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >2638</td>
#                         <td id="T_b2e6f526_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >896</td>
#                         <td id="T_b2e6f526_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >728</td>
#                         <td id="T_b2e6f526_7688_11ea_ba57_8c85904b4670row0_col3" class="data row0 col3" >603</td>
#                         <td id="T_b2e6f526_7688_11ea_ba57_8c85904b4670row0_col4" class="data row0 col4" >309</td>
#                         <td id="T_b2e6f526_7688_11ea_ba57_8c85904b4670row0_col5" class="data row0 col5" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b2e6f526_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b2e6f526_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >1290</td>
#                         <td id="T_b2e6f526_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >292</td>
#                         <td id="T_b2e6f526_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >146</td>
#                         <td id="T_b2e6f526_7688_11ea_ba57_8c85904b4670row1_col3" class="data row1 col3" >104</td>
#                         <td id="T_b2e6f526_7688_11ea_ba57_8c85904b4670row1_col4" class="data row1 col4" >37</td>
#                         <td id="T_b2e6f526_7688_11ea_ba57_8c85904b4670row1_col5" class="data row1 col5" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b2e6f526_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b2e6f526_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >3928</td>
#                         <td id="T_b2e6f526_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >1188</td>
#                         <td id="T_b2e6f526_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >874</td>
#                         <td id="T_b2e6f526_7688_11ea_ba57_8c85904b4670row2_col3" class="data row2 col3" >707</td>
#                         <td id="T_b2e6f526_7688_11ea_ba57_8c85904b4670row2_col4" class="data row2 col4" >346</td>
#                         <td id="T_b2e6f526_7688_11ea_ba57_8c85904b4670row2_col5" class="data row2 col5" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each TotalCharges_binned:
# TotalCharges_binned
# (-8.685, 1736.96]     0.328411
# (1736.96, 3473.92]    0.245791
# (3473.92, 5210.88]    0.167048
# (5210.88, 6947.84]    0.147100
# (6947.84, 8684.8]     0.106936
# Name: Churn, dtype: float64

# %% [markdown]
# **Decision**: **Include** in the models. We see clear negative correlation between the total charges and churn rate.

# %% [markdown]
# ## 3. Preprocessing of data

# %%
print("We decided to delete columns: " + str(columns_to_delete))
print("We decided to encode columns: " + str(columns_to_encode))

"""
6 columns tell us similar information – whether a customer has a specific service connected {Yes, No, No internet at all}.
However, we have a distinct feature (InternetService) to consider those who don't have internet, so to avoid
multicollinearity, we need to join "No" and "No internet service" in all six columns.
"""
columns_with_no_and_ns = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                          'TechSupport', 'StreamingTV', 'StreamingMovies']

for column in columns_with_no_and_ns:
    data.loc[:,column].replace("No internet service", "No", inplace = True)
    
# Next, we have 2 categories in PaymentMethod with almost identical churn rate. Let's merge them.
data.PaymentMethod = data.PaymentMethod.map({
    'Electronic check': 'Electronic check',
    'Mailed check': 'Mailed check',
    'Bank transfer (automatic)': "Automatic",
    'Credit card (automatic)': "Automatic",
})

# Let's generate a new feature - total number of online services connected.
data['NumberOnlineServices'] = np.where(data.OnlineSecurity == 'Yes', 1, 0) + \
                               np.where(data.OnlineBackup == 'Yes', 1, 0) + \
                               np.where(data.DeviceProtection == 'Yes', 1, 0) + \
                               np.where(data.TechSupport == 'Yes', 1, 0) + \
                               np.where(data.StreamingTV == 'Yes', 1, 0) + \
                               np.where(data.StreamingMovies == 'Yes', 1, 0)
                               
plot_crosstab_and_value_counts_againts_target('NumberOnlineServices')

print("Starting the deletion and encoding, as requested...")
# Here we drop and encode all columns which we marked for deletion or encoding.
data.drop(columns_to_delete, axis = 1, inplace = True)
data = pd.get_dummies(data,
                      columns = columns_to_encode,
                      drop_first = True
                      )
print("Deletion and encoding finished")

# Separate y and X
y = data.Churn
X = data.drop('Churn', axis = 1)
# Out:
# We decided to delete columns: ['customerID', 'gender', 'PhoneService', 'MultipleLines', 'StreamingTV', 'StreamingMovies']
# We decided to encode columns: ['Partner', 'Dependents', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'Contract', 'PaperlessBilling', 'PaymentMethod']
# Count of values: NumberOnlineServices versus Churn:
# <style  type="text/css" >
#     #T_b2f39c54_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  #45a266;
#             color:  #000000;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row0_col1 {
#             background-color:  #d7eb66;
#             color:  #000000;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  #8ec666;
#             color:  #000000;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row0_col3 {
#             background-color:  #60b066;
#             color:  #000000;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row0_col4 {
#             background-color:  #49a466;
#             color:  #000000;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row0_col5 {
#             background-color:  #249266;
#             color:  #000000;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row0_col6 {
#             background-color:  #0e8666;
#             color:  #000000;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row0_col7 {
#             background-color:  #5cae66;
#             color:  #000000;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row1_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row1_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row1_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row1_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row2_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row2_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row2_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row2_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b2f39c54_7688_11ea_ba57_8c85904b4670row2_col7 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b2f39c54_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="index_name level0" >NumberOnlineServices</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >Churn</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b2f39c54_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >1744</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >524</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >663</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row0_col3" class="data row0 col3" >812</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row0_col4" class="data row0 col4" >662</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row0_col5" class="data row0 col5" >500</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row0_col6" class="data row0 col6" >269</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row0_col7" class="data row0 col7" >5174</td>
#             </tr>
#             <tr>
#                         <th id="T_b2f39c54_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >475</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >442</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >370</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row1_col3" class="data row1 col3" >306</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row1_col4" class="data row1 col4" >190</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row1_col5" class="data row1 col5" >71</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row1_col6" class="data row1 col6" >15</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row1_col7" class="data row1 col7" >1869</td>
#             </tr>
#             <tr>
#                         <th id="T_b2f39c54_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >2219</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >966</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >1033</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row2_col3" class="data row2 col3" >1118</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row2_col4" class="data row2 col4" >852</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row2_col5" class="data row2 col5" >571</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row2_col6" class="data row2 col6" >284</td>
#                         <td id="T_b2f39c54_7688_11ea_ba57_8c85904b4670row2_col7" class="data row2 col7" >7043</td>
#             </tr>
#     </tbody></table>
# Average churn rate for each NumberOnlineServices:
# NumberOnlineServices
# 1    0.457557
# 2    0.358180
# 3    0.273703
# 4    0.223005
# 0    0.214060
# 5    0.124343
# 6    0.052817
# Name: Churn, dtype: float64
# Starting the deletion and encoding, as requested...
# Deletion and encoding finished

# %% [markdown]
# ## 4. Creating 5 alternative models
# Most ML models have **hyperparameters** – parameters that should be specified before fitting the model. The process of choosing optimal hyperparameters is called **hyperparameters tuning**, and that's exactly what I do here.
#
# Let me introduce another concept – **regularization**. Regularization is the process of making a model more able to catch general trends instead of train-specific trends, by modifying the loss function. 'C' hyperparameter in logistic regression (and in many other models) is responsible for it. Low C-values lead to lower train score and higher test score, because the model becomes able to catch general trends better. However, excessively low c-values will make a model not able to catch any trends at all.
#
# For each of the five models, my approach would be:
# 1. Compare models with different key hyperparameter's values.
# 1. Select the optimal value of key hyperparameter, based on highest cross-validated precision.
# 1. Compare the best versions of each of the 5 models with each other.
#
# Also, before running it, I'd like to specify that in this project my **target metric is precision**.
# **Precision** in general is the fraction of relevant instances among the retrieved instances. In this problem, it is a fraction of clients who did churn among those which were selected by the model as likely to churn. Precision reaches its best value at 1 and worst score at 0.
#
# I'm choosing precision for 2 reasons:
# - To provide business value for telecoms, it is better for this model to have lower recall but higher precision than vice versa. Predicting too much churn would mean losing money on ads which try to get people back while they don't plan to leave. On the other hand, we know that conversion rates of ads targeted to people who really want to churn are quite low, so we should spend them only for those who are really likely to churn.
# - We are facing a problem of imbalanced classes, and accuracy makes no sense in such problems.

# %%
# Import functions which will be used in all models
from sklearn.model_selection import cross_val_score, ShuffleSplit
# Create a split object – it will be used in all models.
split = ShuffleSplit(n_splits=3, test_size=0.25, random_state=1111)

# %% [markdown]
# ### Model 1: Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# Define an empty list to store precision for different hyperparameters
lr_precisions = list()

# Values of C to be checked
lr_C_values = [0.001, 0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.4, 0.5, 1, 2, 3, 4, 5]

# Loop over C values to find an optimal
for C_value in lr_C_values:
    
    # Create LogisticRegression object
    lr_foropt = LogisticRegression(solver = 'liblinear', penalty = 'l1', C = C_value, max_iter=1000)
    
    # Fit it to the cross validator
    lr_cv_results_list = cross_val_score(lr_foropt, X, y, cv = split, scoring = 'precision')
    
    # Compute the mean precision
    lr_avg_precision = np.mean(lr_cv_results_list)
    
    # Append this mean to the list of precisions
    lr_precisions.append(lr_avg_precision)
    
# Plot the results
plt.plot(lr_C_values, lr_precisions)
plt.title('C-value optimization')
plt.ylabel('Cross-validated precision score')
plt.xlabel('C value')
plt.show()

# Print the value of C-hyperparameter which was found optimal
lr_optimalC = lr_C_values[lr_precisions.index(max(lr_precisions))]
print('Optimal c-value: ', lr_optimalC)

# Create logistic regression with our optimal hyperparameter
lr = LogisticRegression(solver = 'liblinear', penalty = 'l1', C = lr_optimalC, max_iter=1000)
# Out:
# Optimal c-value:  0.05

# %% [markdown]
# ### Model 2: Decision Tree Classifier
# In this classificator I'll tune 2 hyperparameters: criterion and max_depth of the tree. The instrument for tuning more that 1 hyperparameter is called **Grid Search**, and I apply it here:

# %%
# Import DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier

# Initialize a standard classifier
dt_foropt = DecisionTreeClassifier()

# Import GridSearchCV package
from sklearn.model_selection import GridSearchCV

# Instantiate the GridSearchCV object and run the search
parameters_dt = {'criterion':['gini', 'entropy'],
                 'max_depth': np.arange(3,100,2)}

searcher_dt = GridSearchCV(dt_foropt, parameters_dt, cv = split, scoring = 'precision')
searcher_dt.fit(X, y)

# Report the best parameters and the corresponding score
print("Best CV params", searcher_dt.best_params_)

# Initialize a classifier with optimal parameters
dt = DecisionTreeClassifier(criterion = searcher_dt.best_params_['criterion'],
                            max_depth = searcher_dt.best_params_['max_depth'],
                            class_weight = 'balanced')
# Out:
# Best CV params {'criterion': 'gini', 'max_depth': 3}

# %% [markdown]
# ### Model 3: KNN Classifier
# The key hyperparameter of KNN is K – the number of neighbors to consider in voting.

# %%
# Import KNN from scikit learn
from sklearn.neighbors import KNeighborsClassifier

# Define an empty list to store precision for different hyperparameters
knn_precisions = list()

# Values of K to be checked
neighbors = np.arange(1,50,2)

# Loop over K values to find an optimal
for k in neighbors:
    
    # Create KNeighborsClassifier object
    knn_foropt = KNeighborsClassifier(n_neighbors = k)
    
    # Fit it to the cross validator
    knn_cv_results_list = cross_val_score(knn_foropt, X, y, cv = split, scoring = 'precision')
    
    # Compute the mean precision
    knn_avg_precision = np.mean(knn_cv_results_list)
    
    # Append this mean to the list of precision scores
    knn_precisions.append(knn_avg_precision)
    
# Plot the results
plt.plot(neighbors, knn_precisions)
plt.title('K value optimization')
plt.ylabel('Cross-validated precision')
plt.xlabel('Neighbors')
plt.show()

# Print the value of K-hyperparameter which was found optimal
knn_optimal_k = neighbors[knn_precisions.index(max(knn_precisions))]
print('Optimal number of neighbors: ', knn_optimal_k)

# Create a model with our optimal hyperparameter
knn = KNeighborsClassifier(n_neighbors = knn_optimal_k)
# Out:
# Optimal number of neighbors:  39

# %% [markdown]
# ### Model 4: CatBoost Classifier
# CatBoost Classifier is based on decision trees. It's key hyperparameter, according to the documentation, is the regularization strength, called "l2_leaf_reg".

# %%
from catboost import CatBoostClassifier

# Define an empty list to store precision for different hyperparameters
cbr_precisions = list()

# Values of l2_leaf_reg to be checked
l2_values = [0.01, 0.1, 0.25, 0.5, 1, 2, 3, 5, 10, 20, 50, 100, 200]

# Loop over l2_leaf_reg values to find an optimal
for l2 in l2_values:
    
    # Create CatBoostClassifier object
    cbr_foropt = CatBoostClassifier(l2_leaf_reg = l2, silent = True)
    
    # Fit it to the cross validator
    cv_results_list_cbr = cross_val_score(cbr_foropt, X, y, cv = split, scoring = 'precision')
    
    # Compute the mean precision
    cbr_avg_precision = np.mean(cv_results_list_cbr)
    
    # Append this mean to the list of precisions
    cbr_precisions.append(cbr_avg_precision)
    
# Plot the results
plt.plot(l2_values, cbr_precisions)
plt.title('CBR optimization')
plt.ylabel('Precision')
plt.xlabel('l2_leaf_reg')
plt.show()

# Print the value of l2-hyperparameter which was found optimal
optimal_l2 = l2_values[cbr_precisions.index(max(cbr_precisions))]
print('Optimal l2-value: ', optimal_l2)

# Create CatBoostClassifier with our optimal hyperparameter
cbr = CatBoostClassifier(l2_leaf_reg = optimal_l2, silent = True)
# Out:
# Optimal l2-value:  100

# %% [markdown]
# ### Model 5. AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

ada = AdaBoostClassifier(n_estimators = 100)

# %% [markdown]
# ## 5. Comparing models

# %%
from sklearn.metrics import plot_confusion_matrix, roc_curve, auc, accuracy_score, precision_score, recall_score, f1_score

def print_report_for_classifier(model, model_name = 'unnamed classifier'):
    """This function takes and UNtrained but created model object and its verbose name as parametets,
    and prints a report with its performance of the entire dataset.
    Please, note, that this report assumes that we test the model on the same data as we use to train it,
    because we've already tuned the hyperparameters in a way to aviod overfitting."""
    
    model.fit(X, y)
    y_pred = model.predict(X)
    
    # Calculate necessary data for ROC/AUC
    fpr, tpr, thresholds = roc_curve(y, y_pred)
    area = auc(fpr, tpr)

    print("Report for {}:".format(model_name))
    print('-'*100)
    
    # The next block of code just creates a figure with 2 charts
    fig = plt.figure(figsize = (8, 4), dpi = 100)

    axes11 = fig.add_subplot(121)
    plot_confusion_matrix(model, X, y, cmap = 'summer_r', values_format = "1", ax = axes11)
    axes11.set_title('Confusion matrix')

    axes12 = fig.add_subplot(122)
    axes12.plot(fpr, tpr, color = 'orange', label = "ROC curve (area = {:.2f})".format(area))
    axes12.plot([0,1], [0,1], linestyle='--', label = 'Diagonal')
    axes12.set_xlim([0,1])
    axes12.set_ylim([0,1.05])
    axes12.set_xlabel('False Positive Rate')
    axes12.set_ylabel('True Positive Rate')
    axes12.set_title('ROC')
    axes12.legend()

    plt.tight_layout()
    plt.show()
    print('-'*100)
    
    # We include 4 key metrics in our report
    accuracy = accuracy_score(y, y_pred)
    precision = precision_score(y, y_pred)
    recall = recall_score(y, y_pred)
    f1 = f1_score(y, y_pred)

    print('Accuracy: ', round(accuracy, 2))
    print('Precision: ', round(precision, 2))
    print('Recall: ', round(recall, 2))
    print('F1: ', round(f1, 2))
    print('AUC: ', round(area, 2))
    print('-'*100)

def display_comparison_table(models_with_names):

    column_names = ["Model", "Precision", "Recall", "F1", "Accuracy", "AUC"]
    df = pd.DataFrame(columns = column_names)

    for model, name in models_with_names:

        model.fit(X, y)
        y_pred = model.predict(X)
        fpr, tpr, thresholds = roc_curve(y, y_pred)

        precision = precision_score(y, y_pred)
        recall = recall_score(y, y_pred)
        f1 = f1_score(y, y_pred)
        accuracy = accuracy_score(y, y_pred)
        area = auc(fpr, tpr)

        df = df.append({
            "Model": name,
            "Precision": precision,
            "Recall": recall,
            "F1": f1,
            "Accuracy": accuracy,
            "AUC": area
        }, ignore_index = True)

    def highlight_max_value_in_each_column(s):
        is_max = s == s.max()
        return ['background-color: PaleGreen' if v else '' for v in is_max]    

    df = df.set_index('Model').sort_values(by = 'Precision', ascending = False)

    display(
        df.style\
            .apply(highlight_max_value_in_each_column)\
            .set_precision(2)
    )

# Declare all models which we used
models_with_names = [
    (lr, 'Logistic Regression'),
    (dt, 'Decision Tree'),
    (knn, 'KNN classifier'),
    (cbr, 'CatBoost Classifier'),
    (ada, 'AdaBoost Classifier')
]    

display_comparison_table(models_with_names)
# Out:
# <style  type="text/css" >
#     #T_f50a8b48_7688_11ea_ba57_8c85904b4670row0_col0 {
#             background-color:  PaleGreen;
#         }    #T_f50a8b48_7688_11ea_ba57_8c85904b4670row0_col2 {
#             background-color:  PaleGreen;
#         }    #T_f50a8b48_7688_11ea_ba57_8c85904b4670row0_col3 {
#             background-color:  PaleGreen;
#         }    #T_f50a8b48_7688_11ea_ba57_8c85904b4670row0_col4 {
#             background-color:  PaleGreen;
#         }    #T_f50a8b48_7688_11ea_ba57_8c85904b4670row4_col1 {
#             background-color:  PaleGreen;
#         }</style><table id="T_f50a8b48_7688_11ea_ba57_8c85904b4670" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Precision</th>        <th class="col_heading level0 col1" >Recall</th>        <th class="col_heading level0 col2" >F1</th>        <th class="col_heading level0 col3" >Accuracy</th>        <th class="col_heading level0 col4" >AUC</th>    </tr>    <tr>        <th class="index_name level0" >Model</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f50a8b48_7688_11ea_ba57_8c85904b4670level0_row0" class="row_heading level0 row0" >CatBoost Classifier</th>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row0_col0" class="data row0 col0" >0.73</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row0_col1" class="data row0 col1" >0.58</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row0_col2" class="data row0 col2" >0.64</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row0_col3" class="data row0 col3" >0.83</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row0_col4" class="data row0 col4" >0.75</td>
#             </tr>
#             <tr>
#                         <th id="T_f50a8b48_7688_11ea_ba57_8c85904b4670level0_row1" class="row_heading level0 row1" >KNN classifier</th>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row1_col0" class="data row1 col0" >0.70</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row1_col1" class="data row1 col1" >0.38</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row1_col2" class="data row1 col2" >0.50</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row1_col3" class="data row1 col3" >0.79</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row1_col4" class="data row1 col4" >0.66</td>
#             </tr>
#             <tr>
#                         <th id="T_f50a8b48_7688_11ea_ba57_8c85904b4670level0_row2" class="row_heading level0 row2" >AdaBoost Classifier</th>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row2_col0" class="data row2 col0" >0.67</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row2_col1" class="data row2 col1" >0.54</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row2_col2" class="data row2 col2" >0.60</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row2_col3" class="data row2 col3" >0.81</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row2_col4" class="data row2 col4" >0.72</td>
#             </tr>
#             <tr>
#                         <th id="T_f50a8b48_7688_11ea_ba57_8c85904b4670level0_row3" class="row_heading level0 row3" >Logistic Regression</th>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row3_col0" class="data row3 col0" >0.66</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row3_col1" class="data row3 col1" >0.54</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row3_col2" class="data row3 col2" >0.59</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row3_col3" class="data row3 col3" >0.80</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row3_col4" class="data row3 col4" >0.72</td>
#             </tr>
#             <tr>
#                         <th id="T_f50a8b48_7688_11ea_ba57_8c85904b4670level0_row4" class="row_heading level0 row4" >Decision Tree</th>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row4_col0" class="data row4 col0" >0.43</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row4_col1" class="data row4 col1" >0.89</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row4_col2" class="data row4 col2" >0.58</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row4_col3" class="data row4 col3" >0.65</td>
#                         <td id="T_f50a8b48_7688_11ea_ba57_8c85904b4670row4_col4" class="data row4 col4" >0.73</td>
#             </tr>
#     </tbody></table>

# %%
for model, name in models_with_names:
    print_report_for_classifier(model, name)
# Out:
# Report for Logistic Regression:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Accuracy:  0.8
# Precision:  0.66
# Recall:  0.54
# F1:  0.59
# AUC:  0.72
# ----------------------------------------------------------------------------------------------------
# Report for Decision Tree:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Accuracy:  0.65
# Precision:  0.43
# Recall:  0.89
# F1:  0.58
# AUC:  0.73
# ----------------------------------------------------------------------------------------------------
# Report for KNN classifier:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Accuracy:  0.79
# Precision:  0.7
# Recall:  0.38
# F1:  0.5
# AUC:  0.66
# ----------------------------------------------------------------------------------------------------
# Report for CatBoost Classifier:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Accuracy:  0.83
# Precision:  0.73
# Recall:  0.58
# F1:  0.64
# AUC:  0.75
# ----------------------------------------------------------------------------------------------------
# Report for AdaBoost Classifier:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Accuracy:  0.81
# Precision:  0.67
# Recall:  0.54
# F1:  0.6
# AUC:  0.72
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 6. Making conclusions
# According to our criteria – precision, the best model is **CatBoost Classifier**. It gives us not only the best precision, but the best values for accuracy, AUC and F1 score. The optimal l2_leaf_reg value is 100.
